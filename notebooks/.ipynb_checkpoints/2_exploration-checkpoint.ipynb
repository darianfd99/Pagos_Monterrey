# %%
# %matplotlib inline
import matplotlib
import pandas as pd 
import matplotlib.pyplot as plt 
matplotlib.style.use("seaborn")

# %%
df = pd.read_csv("data/clean_compras.csv")

# %%
df.head()
# Out:
#    NUM BEN                                    BENEFICIARIO           RFC  \
# 0   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 1   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 2   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 3   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 4   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
#
#                   FACTURA      CONTRATO  \
# 0  LLS AF8458-158008-3972  OT. 20204373
# 1  LLS PF6916-158008-4041  OT. 20204425
# 2  LLS PF6917-158008-3975  OT. 20204376
# 3  LLS PF7004-158008-3971  OT. 20204374
# 4  LLS PF7137-158008-4554  OT. 20205130
#
#                                             CONCEPTO TIPO         # OP  \
# 0  REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR    1019110.0
# 1  REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR    1019110.0
# 2  REEMPLAZO DE DOS RINES  (17). PATRIMONIO 80383...   TR    1019110.0
# 3  REEMPLAZO DE  DOS RINES  (14). PATRIMONIO 8007...   TR    1019110.0
# 4  REEMPLAZO E INSTALACION DE RIN 14. PATRIMONIO ...   TR  299001496.0
#
#         FECHA   IMPORTE          SHEET
# 0  2020-12-11  14911.80  GASTOS_VARIOS
# 1  2020-12-11   2528.80  GASTOS_VARIOS
# 2  2020-12-11   8500.02  GASTOS_VARIOS
# 3  2020-12-11   2400.01  GASTOS_VARIOS
# 4  2020-12-23   1537.00  GASTOS_VARIOS

# %% [markdown]
# ## Visión general del datasets

# %%
df.columns
# Out:
# Index(['NUM BEN', 'BENEFICIARIO', 'RFC', 'FACTURA', 'CONTRATO', 'CONCEPTO',
#        'TIPO', '# OP', 'FECHA', 'IMPORTE', 'SHEET'],
#       dtype='object')

# %%
df.dtypes
# Out:
# NUM BEN           int64
# BENEFICIARIO     object
# RFC              object
# FACTURA          object
# CONTRATO         object
# CONCEPTO         object
# TIPO             object
# # OP            float64
# FECHA            object
# IMPORTE         float64
# SHEET            object
# dtype: object

# %%
df.describe()
# Out:
#              NUM BEN          # OP       IMPORTE
# count    1540.000000  1.540000e+03  1.540000e+03
# mean   203914.777273  1.920050e+08  6.263179e+05
# std     92435.932025  1.411189e+08  4.666912e+06
# min    110152.000000  1.019042e+06  8.600000e-01
# 25%    116223.000000  1.019144e+06  2.987000e+03
# 50%    203013.000000  2.980000e+08  1.235584e+04
# 75%    311250.000000  3.000001e+08  1.130583e+05
# max    370012.000000  6.040001e+08  1.267303e+08

# %%
df = df[["BENEFICIARIO", "FACTURA", "CONTRATO", "CONCEPTO", "TIPO", "# OP", "FECHA", "IMPORTE", "SHEET"]]

# %%
df.head()
# Out:
#                                      BENEFICIARIO                 FACTURA  \
# 0  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LLS AF8458-158008-3972
# 1  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LLS PF6916-158008-4041
# 2  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LLS PF6917-158008-3975
# 3  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LLS PF7004-158008-3971
# 4  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LLS PF7137-158008-4554
#
#        CONTRATO                                           CONCEPTO TIPO  \
# 0  OT. 20204373  REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR
# 1  OT. 20204425  REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR
# 2  OT. 20204376  REEMPLAZO DE DOS RINES  (17). PATRIMONIO 80383...   TR
# 3  OT. 20204374  REEMPLAZO DE  DOS RINES  (14). PATRIMONIO 8007...   TR
# 4  OT. 20205130  REEMPLAZO E INSTALACION DE RIN 14. PATRIMONIO ...   TR
#
#           # OP       FECHA   IMPORTE          SHEET
# 0    1019110.0  2020-12-11  14911.80  GASTOS_VARIOS
# 1    1019110.0  2020-12-11   2528.80  GASTOS_VARIOS
# 2    1019110.0  2020-12-11   8500.02  GASTOS_VARIOS
# 3    1019110.0  2020-12-11   2400.01  GASTOS_VARIOS
# 4  299001496.0  2020-12-23   1537.00  GASTOS_VARIOS

# %% [markdown]
# ## Análisis unidimensional de las variables

# %%
df["SHEET"].value_counts()
# Out:
# CONTRATISTAS_Y_FDO_FED    724
# GASTOS_VARIOS             690
# COMUNICACION               71
# SERV._PERS.                46
# SERV_PPROF                  9
# Name: SHEET, dtype: int64

# %%
len(list(df['CONCEPTO'].value_counts()))
# Out:
# 1396

# %%
df['BENEFICIARIO'].value_counts()[0:10]
# Out:
# CAMARA MEXICANA DE LA INDUSTRIA DE LA CONSTRUCCION    266
# AUTOKAM REGIOMONTANA,S.A.DE C.V.                      101
# CAR ONE MONTERREY, S.A. DE C.V.                        78
# PEREZ RIOS RAMIRO                                      58
# S.I.M.E.P.R.O.D.E.                                     50
# INTERASFALTOS, S.A. DE C.V.                            45
# GRUPO COYOTE MONTERREY, S.A. DE C.V.                   43
# SERVICIO TECNICO CHURUBUSCO, S.A. DE C.V.              30
# CFE SUMINISTRADOR DE SERVICIOS BASICOS                 29
# CORDERO MACIAS SILVESTRE GUADALUPE                     27
# Name: BENEFICIARIO, dtype: int64

# %%
df['IMPORTE'].hist()

# %%
df[df["IMPORTE"] < df['IMPORTE'].quantile(0.95)]["IMPORTE"].hist()

# %%
df[df["IMPORTE"] < df['IMPORTE'].quantile(0.95)]["IMPORTE"].hist(bins = 50)

# %% [markdown]
# ## Análisis multidimensional de los variables

# %%
sum_importe_beneficiario = df.groupby("BENEFICIARIO").sum()['IMPORTE']
sum_importe_beneficiario
# Out:
# BENEFICIARIO
# 235 PROYECTOS, S.A. DE C.V.                   1649292.36
# ABC Y CONSTRUCCIONES, SA. DE CV.              1311087.90
# ACEROS Y OVEROLLINGS DE MEXICO, SA. DE CV.       5914.30
# ADQUISICIONES INTELIGENTES, S.A. DE C.V.      2132196.00
# ALIANZA AUTOMOTRIZ RIVERO, SA. DE CV.          450859.52
#                                                  ...
# VILLARREAL CARDENAS JUAN IGNACIO                 3733.13
# VILLARREAL CARDENAS NANCY ESTHER                81461.14
# VILLARREAL DE LEON BERTHA                       11004.05
# VIVERO EL ESCORIAL, S.A. DE C.V.              2511255.46
# ZAPATA CHAVIRA HOMERO ARTURO                    28350.00
# Name: IMPORTE, Length: 301, dtype: float64

# %%
sum_importe_beneficiario.reset_index().sort_values(by = "IMPORTE", ascending = False).iloc[0:10].plot(kind = 'bar', x = "BENEFICIARIO", y = "IMPORTE")

# %%
mean_import_sheet = df.groupby("SHEET").mean()['IMPORTE']
mean_import_sheet.reset_index().sort_values(by = "IMPORTE", ascending = False).iloc[0:10].plot(kind = "bar", x = "SHEET", y = "IMPORTE")

# %%
mean_import_sheet.reset_index().sort_values(by = "IMPORTE", ascending = False).iloc[0:10]
# Out:
#                     SHEET        IMPORTE
# 2           GASTOS_VARIOS  881659.731797
# 1  CONTRATISTAS_Y_FDO_FED  474566.765787
# 4              SERV_PPROF  229592.166667
# 0            COMUNICACION  109705.343662
# 3             SERV._PERS.   59623.405217

# %%
sum_importe_fecha = df.groupby("FECHA").sum()["IMPORTE"].plot(kind = "bar")
sum_importe_fecha

# %%
compras_sheet_beneficiarios = df.groupby(["BENEFICIARIO", "SHEET"]).sum()["IMPORTE"].sort_values().unstack('SHEET')
compras_sheet_beneficiarios
# Out:
# SHEET                                       COMUNICACION  \
# BENEFICIARIO
# 235 PROYECTOS, S.A. DE C.V.                          NaN
# ABC Y CONSTRUCCIONES, SA. DE CV.                     NaN
# ACEROS Y OVEROLLINGS DE MEXICO, SA. DE CV.           NaN
# ADQUISICIONES INTELIGENTES, S.A. DE C.V.             NaN
# ALIANZA AUTOMOTRIZ RIVERO, SA. DE CV.                NaN
# ...                                                  ...
# VILLARREAL CARDENAS JUAN IGNACIO                     NaN
# VILLARREAL CARDENAS NANCY ESTHER                     NaN
# VILLARREAL DE LEON BERTHA                            NaN
# VIVERO EL ESCORIAL, S.A. DE C.V.                     NaN
# ZAPATA CHAVIRA HOMERO ARTURO                         NaN
#
# SHEET                                       CONTRATISTAS_Y_FDO_FED  \
# BENEFICIARIO
# 235 PROYECTOS, S.A. DE C.V.                                    NaN
# ABC Y CONSTRUCCIONES, SA. DE CV.                         1311087.9
# ACEROS Y OVEROLLINGS DE MEXICO, SA. DE CV.                     NaN
# ADQUISICIONES INTELIGENTES, S.A. DE C.V.                 2132196.0
# ALIANZA AUTOMOTRIZ RIVERO, SA. DE CV.                          NaN
# ...                                                            ...
# VILLARREAL CARDENAS JUAN IGNACIO                               NaN
# VILLARREAL CARDENAS NANCY ESTHER                               NaN
# VILLARREAL DE LEON BERTHA                                      NaN
# VIVERO EL ESCORIAL, S.A. DE C.V.                               NaN
# ZAPATA CHAVIRA HOMERO ARTURO                                   NaN
#
# SHEET                                       GASTOS_VARIOS  SERV._PERS.  \
# BENEFICIARIO
# 235 PROYECTOS, S.A. DE C.V.                    1649292.36          NaN
# ABC Y CONSTRUCCIONES, SA. DE CV.                      NaN          NaN
# ACEROS Y OVEROLLINGS DE MEXICO, SA. DE CV.        5914.30          NaN
# ADQUISICIONES INTELIGENTES, S.A. DE C.V.              NaN          NaN
# ALIANZA AUTOMOTRIZ RIVERO, SA. DE CV.           450859.52          NaN
# ...                                                   ...          ...
# VILLARREAL CARDENAS JUAN IGNACIO                      NaN      3733.13
# VILLARREAL CARDENAS NANCY ESTHER                      NaN     81461.14
# VILLARREAL DE LEON BERTHA                        11004.05          NaN
# VIVERO EL ESCORIAL, S.A. DE C.V.               2511255.46          NaN
# ZAPATA CHAVIRA HOMERO ARTURO                          NaN          NaN
#
# SHEET                                       SERV_PPROF
# BENEFICIARIO
# 235 PROYECTOS, S.A. DE C.V.                        NaN
# ABC Y CONSTRUCCIONES, SA. DE CV.                   NaN
# ACEROS Y OVEROLLINGS DE MEXICO, SA. DE CV.         NaN
# ADQUISICIONES INTELIGENTES, S.A. DE C.V.           NaN
# ALIANZA AUTOMOTRIZ RIVERO, SA. DE CV.              NaN
# ...                                                ...
# VILLARREAL CARDENAS JUAN IGNACIO                   NaN
# VILLARREAL CARDENAS NANCY ESTHER                   NaN
# VILLARREAL DE LEON BERTHA                          NaN
# VIVERO EL ESCORIAL, S.A. DE C.V.                   NaN
# ZAPATA CHAVIRA HOMERO ARTURO                   28350.0
#
# [301 rows x 5 columns]

# %%
top_beneficiarios = df.groupby("BENEFICIARIO")['IMPORTE'].sum().sort_values(ascending = False).index[0:10]
top_beneficiarios
# Out:
# Index(['MUNICIPIO DE LA CIUDAD DE MONTERREY',
#        'INTEGRACION DE SISTEMAS DE AVANZADA TECNOLOGIA, S.A. DE C.V.',
#        'VALUE ARRENDADORA,S.A.DE C.V. SOFOM ER VALUE GPO.FIN.',
#        'CAR ONE MONTERREY, S.A. DE C.V.',
#        'BANCO BANCREA,S.A. ,FIDEICOMISO NUMERO BP417',
#        'SI VALE MEXICO, S.A. DE C.V.', 'INTERASFALTOS, S.A. DE C.V.',
#        'RED RECOLECTOR, S.A. DE C.V.', 'SERVICIOS BROXEL, S.A.P.I. DE C.V.',
#        'PROYECTOS Y DESARROLLOS SALVE, SA. DE CV.'],
#       dtype='object', name='BENEFICIARIO')

# %%
compras_sheet_beneficiarios.loc[top_beneficiarios]
# Out:
# SHEET                                               COMUNICACION  \
# BENEFICIARIO
# MUNICIPIO DE LA CIUDAD DE MONTERREY                          NaN
# INTEGRACION DE SISTEMAS DE AVANZADA TECNOLOGIA,...           NaN
# VALUE ARRENDADORA,S.A.DE C.V. SOFOM ER VALUE GP...           NaN
# CAR ONE MONTERREY, S.A. DE C.V.                              NaN
# BANCO BANCREA,S.A. ,FIDEICOMISO NUMERO BP417                 NaN
# SI VALE MEXICO, S.A. DE C.V.                                 NaN
# INTERASFALTOS, S.A. DE C.V.                                  NaN
# RED RECOLECTOR, S.A. DE C.V.                                 NaN
# SERVICIOS BROXEL, S.A.P.I. DE C.V.                           NaN
# PROYECTOS Y DESARROLLOS SALVE, SA. DE CV.                    NaN
#
# SHEET                                               CONTRATISTAS_Y_FDO_FED  \
# BENEFICIARIO
# MUNICIPIO DE LA CIUDAD DE MONTERREY                           3.412500e+04
# INTEGRACION DE SISTEMAS DE AVANZADA TECNOLOGIA,...            1.281179e+08
# VALUE ARRENDADORA,S.A.DE C.V. SOFOM ER VALUE GP...                     NaN
# CAR ONE MONTERREY, S.A. DE C.V.                               2.229764e+07
# BANCO BANCREA,S.A. ,FIDEICOMISO NUMERO BP417                           NaN
# SI VALE MEXICO, S.A. DE C.V.                                           NaN
# INTERASFALTOS, S.A. DE C.V.                                            NaN
# RED RECOLECTOR, S.A. DE C.V.                                  1.951267e+07
# SERVICIOS BROXEL, S.A.P.I. DE C.V.                                     NaN
# PROYECTOS Y DESARROLLOS SALVE, SA. DE CV.                     1.888003e+07
#
# SHEET                                               GASTOS_VARIOS  \
# BENEFICIARIO
# MUNICIPIO DE LA CIUDAD DE MONTERREY                  2.526895e+08
# INTEGRACION DE SISTEMAS DE AVANZADA TECNOLOGIA,...   7.493040e+06
# VALUE ARRENDADORA,S.A.DE C.V. SOFOM ER VALUE GP...   4.382056e+07
# CAR ONE MONTERREY, S.A. DE C.V.                      8.346672e+06
# BANCO BANCREA,S.A. ,FIDEICOMISO NUMERO BP417         3.000000e+07
# SI VALE MEXICO, S.A. DE C.V.                         2.600384e+07
# INTERASFALTOS, S.A. DE C.V.                          2.404647e+07
# RED RECOLECTOR, S.A. DE C.V.                                  NaN
# SERVICIOS BROXEL, S.A.P.I. DE C.V.                   1.941272e+07
# PROYECTOS Y DESARROLLOS SALVE, SA. DE CV.                     NaN
#
# SHEET                                               SERV._PERS.  SERV_PPROF
# BENEFICIARIO
# MUNICIPIO DE LA CIUDAD DE MONTERREY                         NaN         NaN
# INTEGRACION DE SISTEMAS DE AVANZADA TECNOLOGIA,...          NaN         NaN
# VALUE ARRENDADORA,S.A.DE C.V. SOFOM ER VALUE GP...          NaN         NaN
# CAR ONE MONTERREY, S.A. DE C.V.                             NaN         NaN
# BANCO BANCREA,S.A. ,FIDEICOMISO NUMERO BP417                NaN         NaN
# SI VALE MEXICO, S.A. DE C.V.                                NaN         NaN
# INTERASFALTOS, S.A. DE C.V.                                 NaN         NaN
# RED RECOLECTOR, S.A. DE C.V.                                NaN         NaN
# SERVICIOS BROXEL, S.A.P.I. DE C.V.                          NaN         NaN
# PROYECTOS Y DESARROLLOS SALVE, SA. DE CV.                   NaN         NaN

# %%
compras_sheet_beneficiarios.loc[top_beneficiarios].plot.bar(stacked = True)

# %% [markdown]
# ## Análisis de texto

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 
print(stopwords.words("spanish"))
# Out:
# ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se', 'las', 'por', 'un', 'para', 'con', 'no', 'una', 'su', 'al', 'lo', 'como', 'más', 'pero', 'sus', 'le', 'ya', 'o', 'este', 'sí', 'porque', 'esta', 'entre', 'cuando', 'muy', 'sin', 'sobre', 'también', 'me', 'hasta', 'hay', 'donde', 'quien', 'desde', 'todo', 'nos', 'durante', 'todos', 'uno', 'les', 'ni', 'contra', 'otros', 'ese', 'eso', 'ante', 'ellos', 'e', 'esto', 'mí', 'antes', 'algunos', 'qué', 'unos', 'yo', 'otro', 'otras', 'otra', 'él', 'tanto', 'esa', 'estos', 'mucho', 'quienes', 'nada', 'muchos', 'cual', 'poco', 'ella', 'estar', 'estas', 'algunas', 'algo', 'nosotros', 'mi', 'mis', 'tú', 'te', 'ti', 'tu', 'tus', 'ellas', 'nosotras', 'vosotros', 'vosotras', 'os', 'mío', 'mía', 'míos', 'mías', 'tuyo', 'tuya', 'tuyos', 'tuyas', 'suyo', 'suya', 'suyos', 'suyas', 'nuestro', 'nuestra', 'nuestros', 'nuestras', 'vuestro', 'vuestra', 'vuestros', 'vuestras', 'esos', 'esas', 'estoy', 'estás', 'está', 'estamos', 'estáis', 'están', 'esté', 'estés', 'estemos', 'estéis', 'estén', 'estaré', 'estarás', 'estará', 'estaremos', 'estaréis', 'estarán', 'estaría', 'estarías', 'estaríamos', 'estaríais', 'estarían', 'estaba', 'estabas', 'estábamos', 'estabais', 'estaban', 'estuve', 'estuviste', 'estuvo', 'estuvimos', 'estuvisteis', 'estuvieron', 'estuviera', 'estuvieras', 'estuviéramos', 'estuvierais', 'estuvieran', 'estuviese', 'estuvieses', 'estuviésemos', 'estuvieseis', 'estuviesen', 'estando', 'estado', 'estada', 'estados', 'estadas', 'estad', 'he', 'has', 'ha', 'hemos', 'habéis', 'han', 'haya', 'hayas', 'hayamos', 'hayáis', 'hayan', 'habré', 'habrás', 'habrá', 'habremos', 'habréis', 'habrán', 'habría', 'habrías', 'habríamos', 'habríais', 'habrían', 'había', 'habías', 'habíamos', 'habíais', 'habían', 'hube', 'hubiste', 'hubo', 'hubimos', 'hubisteis', 'hubieron', 'hubiera', 'hubieras', 'hubiéramos', 'hubierais', 'hubieran', 'hubiese', 'hubieses', 'hubiésemos', 'hubieseis', 'hubiesen', 'habiendo', 'habido', 'habida', 'habidos', 'habidas', 'soy', 'eres', 'es', 'somos', 'sois', 'son', 'sea', 'seas', 'seamos', 'seáis', 'sean', 'seré', 'serás', 'será', 'seremos', 'seréis', 'serán', 'sería', 'serías', 'seríamos', 'seríais', 'serían', 'era', 'eras', 'éramos', 'erais', 'eran', 'fui', 'fuiste', 'fue', 'fuimos', 'fuisteis', 'fueron', 'fuera', 'fueras', 'fuéramos', 'fuerais', 'fueran', 'fuese', 'fueses', 'fuésemos', 'fueseis', 'fuesen', 'sintiendo', 'sentido', 'sentida', 'sentidos', 'sentidas', 'siente', 'sentid', 'tengo', 'tienes', 'tiene', 'tenemos', 'tenéis', 'tienen', 'tenga', 'tengas', 'tengamos', 'tengáis', 'tengan', 'tendré', 'tendrás', 'tendrá', 'tendremos', 'tendréis', 'tendrán', 'tendría', 'tendrías', 'tendríamos', 'tendríais', 'tendrían', 'tenía', 'tenías', 'teníamos', 'teníais', 'tenían', 'tuve', 'tuviste', 'tuvo', 'tuvimos', 'tuvisteis', 'tuvieron', 'tuviera', 'tuvieras', 'tuviéramos', 'tuvierais', 'tuvieran', 'tuviese', 'tuvieses', 'tuviésemos', 'tuvieseis', 'tuviesen', 'teniendo', 'tenido', 'tenida', 'tenidos', 'tenidas', 'tened']
# [nltk_data] Downloading package stopwords to /home/darian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# %%
stopwords_list = stopwords.words('spanish') + ['2020', 'cont', 'millar', 'dpp', 'est', 'op', 'ret', 'mty', 'icom']

# %%
textos_compras = ' '.join([x for x in textos_compras.strip().lower().split(" ") if x not in stopwords_list and len(x)>4])

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color = 'white')
wc.generate(textos_compras)

plt.axis("off")
plt.imshow(wc, interpolation = 'bilinear')
plt.show()

# %%
df
# Out:
#                                         BENEFICIARIO                 FACTURA  \
# 0     LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LLS AF8458-158008-3972
# 1     LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LLS PF6916-158008-4041
# 2     LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LLS PF6917-158008-3975
# 3     LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LLS PF7004-158008-3971
# 4     LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LLS PF7137-158008-4554
# ...                                              ...                     ...
# 1535                            SEGOVIA PAEZ MARCELO      116033-158004-1689
# 1536                            SEGOVIA PAEZ MARCELO      116033-158004-1690
# 1537                    TORRES ACOSTA ROBERTO CARLOS      113052-158004-1725
# 1538                    TOVAR CEDILLO JAVIER ALFONSO       23016-158004-1705
# 1539                VILLARREAL CARDENAS NANCY ESTHER      113711-158004-1711
#
#           CONTRATO                                           CONCEPTO TIPO  \
# 0     OT. 20204373  REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR
# 1     OT. 20204425  REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR
# 2     OT. 20204376  REEMPLAZO DE DOS RINES  (17). PATRIMONIO 80383...   TR
# 3     OT. 20204374  REEMPLAZO DE  DOS RINES  (14). PATRIMONIO 8007...   TR
# 4     OT. 20205130  REEMPLAZO E INSTALACION DE RIN 14. PATRIMONIO ...   TR
# ...            ...                                                ...  ...
# 1535     NO APLICA                                   FINIQUITO 116033   CH
# 1536     NO APLICA                             FONDO PENSIONES 116033   CH
# 1537     NO APLICA                          FONDO DE PENSIONES 113052   CH
# 1538     NO APLICA  PAGO 30%  JUICIO DE AMPARO No. 673/2020 (DICIE...   CH
# 1539     NO APLICA                             FONDO PENSIONES 113711   CH
#
#              # OP       FECHA    IMPORTE          SHEET
# 0       1019110.0  2020-12-11   14911.80  GASTOS_VARIOS
# 1       1019110.0  2020-12-11    2528.80  GASTOS_VARIOS
# 2       1019110.0  2020-12-11    8500.02  GASTOS_VARIOS
# 3       1019110.0  2020-12-11    2400.01  GASTOS_VARIOS
# 4     299001496.0  2020-12-23    1537.00  GASTOS_VARIOS
# ...           ...         ...        ...            ...
# 1535    1104570.0  2020-12-11  183992.72    SERV._PERS.
# 1536    1104571.0  2020-12-11   56430.00    SERV._PERS.
# 1537  299000183.0  2020-12-16    7425.00    SERV._PERS.
# 1538  299000179.0  2020-12-15    4084.68    SERV._PERS.
# 1539    1104567.0  2020-12-11   22575.00    SERV._PERS.
#
# [1540 rows x 9 columns]
